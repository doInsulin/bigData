# %% [markdown]
# ## Activity 03: Exporting a Graph to a File on Disk

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

url = "Dataset/auto-mpg.data"
df = pd.read_csv(url)

# %%
column_names = ['mpg', 'cylinders', 'displacement', 'horsepower', 'weight', 'acceleration', 'year', 'origin', 'name']

# %%
df = pd.read_csv(url, names= column_names, delim_whitespace=True)

# %%
fig, ax = plt.subplots()
df.weight.plot(kind='hist', ax=ax)

# %%
fig.savefig('weight_hist.png')

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# url = "Dataset/diamonds.csv"
# df = pd.read_csv(url)
# print(df)

df=sns.load_dataset("diamonds")
df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
img1=np.log(df["price"])
sns.histplot(img1,edgecolor=None,color='lightblue')
# Out:
# <AxesSubplot:xlabel='price', ylabel='Count'>

# %%
sns.barplot(x='cut',y='price',data=df,hue='color')
# Out:
# <AxesSubplot:xlabel='cut', ylabel='price'>

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
df=sns.load_dataset("mpg")
df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
fig,ax=plt.subplots()
df.groupby('model_year')['mpg'].mean()
x_positions=range(len(mpg_mean))
y_values=mpg_mean.values
ax.plot(x_positions,y_values,markersize=6)
ax.fill_between(x_positions, y_values, y_values+1.5, color='blue', alpha=0.1)
ax.fill_between(x_positions, y_values, y_values-1.5, color='blue', alpha=0.1)
ax.set(xlabel='model_year',ylabel='mileage')
plt.show()

# %%
fig,ax=plt.subplots()
ax.set(xlabel='model_year',ylabel='mpg')
df.groupby('model_year')['mpg'].mean().plot()
# Out:
# <AxesSubplot:xlabel='model_year', ylabel='mpg'>

# %%
df.plot(kind='scatter',x='weight',y='mpg',figsize=(20,10),s=100)
plt.xlabel('wight',fontsize=30)
plt.ylabel('mileage',fontsize=30)
# Out:
# Text(0, 0.5, 'mileage')

# %%
fig,ax=plt.subplots()
ax.set(xlabel='model_year',ylabel='mpg')
df.groupby('model_year')['mpg'].mean().plot()
# Out:
# <AxesSubplot:xlabel='model_year', ylabel='mpg'>

# %%
sns.boxplot(data=df,x='model_year',y='mileage')
df.boxplot(column='mileage',by='model_year')
# Out:
# <AxesSubplot:title={'center':'mpg'}, xlabel='model_year'>

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
df=pd.read_csv("D:\\学\\大数据开发课程设计\\数据开发-张志旺\\数据开发-张志旺\\microsoft_stock.csv")
df.head()
# Out:
#    Unnamed: 0        date   open   high    low  close     volume  adj_close
# 0           0  2000-03-01  89.62  94.09  88.94  90.81  106889800      33.68
# 1           1  2000-03-02  91.81  95.37  91.12  93.37  106932600      34.63
# 2           2  2000-03-03  94.75  98.87  93.87  96.12  101435200      35.65
# 3           3  2000-03-06  96.00  97.37  90.12  90.62   93609400      33.61
# 4           4  2000-03-07  96.12  97.50  91.94  92.87  135061000      34.45

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
df1=pd.read_csv("D:\\学\\大数据开发课程设计\\数据开发-张志旺\\数据开发-张志旺\\google_stock.csv")
df1.head()
# Out:
#    Unnamed: 0        date    open    high     low   close    volume  adj_close
# 0           0  2004-08-19  100.00  104.06   95.96  100.34  22351900     100.34
# 1           1  2004-08-20  101.01  109.08  100.50  108.31  11428600     108.31
# 2           2  2004-08-23  110.75  113.48  109.05  109.40   9137200     109.40
# 3           3  2004-08-24  111.24  111.60  103.57  104.87   7631300     104.87
# 4           4  2004-08-25  104.96  108.00  103.88  106.00   4598900     106.00

# %%
df['date']=pd.to_datetime(df['date'])
df1['date']=pd.to_datetime(df1['date'])
plt.figure(figsize=(12, 6))
plt.plot(df['date'],df['close'],label="microsoft_stock")
plt.plot(df1['date'],df1['close'],label="google_stock",color="red")
plt.xlabel("Year")
plt.ylabel("Stock Price")
plt.legend(loc=1)
plt.grid(True) 
plt.show()
